# %%
import pandas as pd

# %%
Total_emissions= pd.read_csv(r'C:\Users\Admin\Desktop\data\Kaggle datasets\Total Emissions Per Country (2000-2020).csv')
Total_emissions
# Out:
#               Area                        Item  \
# 0      Afghanistan               Crop Residues
# 1      Afghanistan               Crop Residues
# 2      Afghanistan               Crop Residues
# 3      Afghanistan               Crop Residues
# 4      Afghanistan               Crop Residues
# ...            ...                         ...
# 58760         OECD  All sectors without LULUCF
# 58761         OECD  All sectors without LULUCF
# 58762         OECD  All sectors without LULUCF
# 58763         OECD  All sectors without LULUCF
# 58764         OECD  All sectors without LULUCF
#
#                                     Element        Unit          2000  \
# 0                    Direct emissions (N2O)  kilotonnes  5.200000e-01
# 1                  Indirect emissions (N2O)  kilotonnes  1.170000e-01
# 2                           Emissions (N2O)  kilotonnes  6.370000e-01
# 3          Emissions (CO2eq) from N2O (AR5)  kilotonnes  1.688070e+02
# ...

# %%
Total_emissions.head()
# Out:
#           Area           Item                           Element        Unit  \
# 0  Afghanistan  Crop Residues            Direct emissions (N2O)  kilotonnes
# 1  Afghanistan  Crop Residues          Indirect emissions (N2O)  kilotonnes
# 2  Afghanistan  Crop Residues                   Emissions (N2O)  kilotonnes
# 3  Afghanistan  Crop Residues  Emissions (CO2eq) from N2O (AR5)  kilotonnes
# 4  Afghanistan  Crop Residues           Emissions (CO2eq) (AR5)  kilotonnes
#
#       2000      2001      2002      2003      2004      2005  ...      2011  \
# 0    0.520    0.5267    0.8200    0.9988    0.8225    1.1821  ...    1.0321
# 1    0.117    0.1185    0.1845    0.2247    0.1851    0.2660  ...    0.2322
# 2    0.637    0.6452    1.0045    1.2235    1.0075    1.4481  ...    1.2643
# 3  168.807  170.9884  266.1975  324.2195  266.9995  383.7498  ...  335.0379
# 4  168.807  170.9884  266.1975  324.2195  266.9995  383.7498  ...  335.0379
#
# ...

# %%
Total_emissions.iloc[2:5]
# Out:
#           Area           Item                           Element        Unit  \
# 2  Afghanistan  Crop Residues                   Emissions (N2O)  kilotonnes
# 3  Afghanistan  Crop Residues  Emissions (CO2eq) from N2O (AR5)  kilotonnes
# 4  Afghanistan  Crop Residues           Emissions (CO2eq) (AR5)  kilotonnes
#
#       2000      2001      2002      2003      2004      2005  ...      2011  \
# 2    0.637    0.6452    1.0045    1.2235    1.0075    1.4481  ...    1.2643
# 3  168.807  170.9884  266.1975  324.2195  266.9995  383.7498  ...  335.0379
# 4  168.807  170.9884  266.1975  324.2195  266.9995  383.7498  ...  335.0379
#
#        2012      2013      2014      2015      2016      2017      2018  \
# 2    1.6815    1.7173    1.7865    1.5220    1.4627    1.3005    1.1011
# 3  445.5958  455.0727  473.4174  403.3181  387.6130  344.6447  291.7838
# 4  445.5958  455.0727  473.4174  403.3181  387.6130  344.6447  291.7838
#
#        2019      2020
# 2    1.4916    1.6133
# ...

# %%
#List of column names in the dataset
Total_emissions.columns
# Out:
# Index(['Area', 'Item', 'Element', 'Unit', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %% [markdown]
# - This code uses the isna() method to check for missing values (NaN values) in the dataset,
# - uses the sum() method to count the number of missing values in each column. Here's the code:

# %%
Total_emissions.isna().sum()
# Out:
# Area          0
# Item          0
# Element       0
# Unit          0
# 2000       3188
# 2001       4727
# 2002       4628
# 2003       4607
# 2004       4602
# 2005       4334
# 2006       4292
# 2007       4450
# 2008       4469
# 2009       4482
# 2010       4051
# 2011       4629
# 2012       4151
# 2013       4264
# 2014       4386
# 2015       4476
# 2016       4513
# 2017       4689
# 2018       4741
# 2019       4777
# 2020       5094
# dtype: int64

# %% [markdown]
# - Use the duplicated() method to check for duplicate rows in the dataset.

# %%
duplicated_rows= Total_emissions.duplicated().sum()
print('Number of duplicated rows:' ,duplicated_rows)
# Out:
# Number of duplicated rows: 2

# %% [markdown]
# * use the drop_duplicates() to remove the duplicated rows from the dataset.
# * The inplace=True parameter ensures that the changes are made to the original DataFrame.
# * After running this code, the duplicated rows will be removed from the dataset.

# %%
Total_emissions.drop_duplicates(inplace=True)
